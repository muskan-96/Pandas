# %%
import requests
from bs4 import BeautifulSoup

# %%
title=str(input("Enter the topic:")).replace(' ','+')
link='https://www.google.com/search?q='+title +'+wikipedia'
print(title)
# Out:
# Enter the topic: martin luthar king
# martin+luthar+king

# %%
link
# Out:
# 'https://www.google.com/search?q=martin+luthar+king+wikipedia'
