# %%
from selenium import webdriver
# !pip install chromedriver_binary
# Out:
# Collecting chromedriver_binary
#   Downloading chromedriver_binary-147.0.7694.0.0.tar.gz (5.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: chromedriver_binary
#   Building wheel for chromedriver_binary (setup.py): started
#   Building wheel for chromedriver_binary (setup.py): finished with status 'done'
#   Created wheel for chromedriver_binary: filename=chromedriver_binary-147.0.7694.0.0-py3-none-any.whl size=10221237 sha256=9d13f64d12c258f4580965152e2fc49238e89f78be4cb5ceaf433307d5f5dc11
#   Stored in directory: c:\users\muskan\appdata\local\pip\cache\wheels\a8\a1\9e\bd722fbfd18a760fde56a1835d2f2bfac5b349525591cf9356
# Successfully built chromedriver_binary
# Installing collected packages: chromedriver_binary
# Successfully installed chromedriver_binary-147.0.7694.0.0

# %%
import chromedriver_binary

# %%
webdriver.Chrome()
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e2970e59eabc623e80f974469e033e44")>

# %%
chromedriver_binary.chromedriver_filename
# Out:
# 'C:\\Users\\Muskan\\anaconda3\\Lib\\site-packages\\chromedriver_binary\\chromedriver.exe'

# %%
import chromedriver_autoinstaller
from selenium import webdriver

chromedriver_autoinstaller.install()  # installs matching driver
driver = webdriver.Chrome()  # no manual path needed

# %%
pip install chromedriver-autoinstaller
# Out:
# Collecting chromedriver-autoinstallerNote: you may need to restart the kernel to use updated packages.
#
#   Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: packaging>=23.1 in c:\users\muskan\anaconda3\lib\site-packages (from chromedriver-autoinstaller) (24.2)
# Downloading chromedriver_autoinstaller-0.6.4-py3-none-any.whl (7.6 kB)
# Installing collected packages: chromedriver-autoinstaller
# Successfully installed chromedriver-autoinstaller-0.6.4
