# %%
import requests
from bs4 import BeautifulSoup

link = 'https://www.youtube.com/@GeeksforGeeksVideos/videos'

# %%
res = requests.get(link)

# %%
soup=BeautifulSoup(res.text,'html.parser')

# %%
soup.text
# Out:
# 'GeeksforGeeks - YouTubeحولالصحافةحقوق الطبع والنشرالتواصل معناصنّاع المحتوىالإعلانمطوّرو البرامجالأحكامالخصوصيةالسياسة والأمانآلية عمل YouTubeتجربة الميزات الجديدة© 2026 Google LLC'

# %%
# as you can see we are not getting the data

# %%
soup.find_all('a')[5]
# Out:
# <a href="/t/contact_us/" slot="guide-links-primary" style="display: none;">التواصل معنا</a>

# %% [raw]
# #We use WebDrivers because they allow our code to control a real web browser programmatically.
#
# 🔹 Reasons:
#
# Automate browser actions
#
# Click buttons, fill forms, scroll pages, navigate links automatically.
#
# Scrape dynamic content
#
# Websites often load data with JavaScript, which requests can’t see. WebDriver renders the page fully.
#
# Testing websites
#
# Automate testing workflows to check if web pages work as expected.
#
# Simulate a real user
#
# Some sites block bots; using WebDriver mimics human interaction, making automation more reliable.
#
# ✅ In short:
#
# WebDriver is used to control a browser so that we can automate tasks, scrape dynamic content, and test websites.
