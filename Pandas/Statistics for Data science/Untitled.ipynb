# %%
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset=[11,10,12,14,12,15,14,13,15,102,12,14,17,19,107,10,13,12,11,14,13,15,1,15,12,10,14,13,15,10]

# %%
plt.hist(dataset)
# Out:
# (array([ 7., 21.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  2.]),
#  array([  1. ,  11.6,  22.2,  32.8,  43.4,  54. ,  64.6,  75.2,  85.8,
#          96.4, 107. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # nnnnTo find out outlier we will use two techniques 1)zscore

# %%
outliers=[]

# %%
def detect_outliers(data):
    threshold=3 ##3rd standard deviation
    mean=np.mean(data)
    std=np.std(data)
